# %%
#importing required libraries

import numpy as np 
import pandas as pd 

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df = pd.read_csv("Shark Tank India.csv")
df.head(3)
# Out:
#    Season Number Season Start Season End  Episode Number  \
# 0              1    20-Dec-21  04-Feb-22               1
# 1              1    20-Dec-21  04-Feb-22               1
# 2              1    20-Dec-21  04-Feb-22               1
#
#                  Episode Title  Pitch Number      Startup Name  \
# 0  Badlegi Business Ki Tasveer             1     BluePineFoods
# 1  Badlegi Business Ki Tasveer             2      BoozScooters
# 2  Badlegi Business Ki Tasveer             3  HeartUpMySleeves
#
#                        Industry  \
# 0                          Food
# 1  Vehicles/Electrical Vehicles
# 2                Beauty/Fashion
#
#                             Business Description  \
# 0                                   Frozen Momos
# 1  Renting e-bike for mobility in private spaces
# 2                             Detachable Sleeves
#
#                  Company Website  ...  Ghazal Investment Amount  \
# 0     https://bluepinefoods.com/  ...                       NaN
# ...

# %%
df.head(5)
# Out:
#    Season Number Season Start Season End  Episode Number  \
# 0              1    20-Dec-21  04-Feb-22               1
# 1              1    20-Dec-21  04-Feb-22               1
# 2              1    20-Dec-21  04-Feb-22               1
# 3              1    20-Dec-21  04-Feb-22               2
# 4              1    20-Dec-21  04-Feb-22               2
#
#                  Episode Title  Pitch Number      Startup Name  \
# 0  Badlegi Business Ki Tasveer             1     BluePineFoods
# 1  Badlegi Business Ki Tasveer             2      BoozScooters
# 2  Badlegi Business Ki Tasveer             3  HeartUpMySleeves
# 3      Insaan, Ideas Aur Sapne             4         TagzFoods
# 4      Insaan, Ideas Aur Sapne             5      HeadAndHeart
#
#                        Industry  \
# 0                          Food
# 1  Vehicles/Electrical Vehicles
# 2                Beauty/Fashion
# 3                          Food
# 4                     Education
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 64 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Season Number              320 non-null    int64
#  1   Season Start               320 non-null    object
#  2   Season End                 320 non-null    object
#  3   Episode Number             320 non-null    int64
#  4   Episode Title              320 non-null    object
#  5   Pitch Number               320 non-null    int64
#  6   Startup Name               320 non-null    object
#  7   Industry                   320 non-null    object
#  8   Business Description       320 non-null    object
#  9   Company Website            309 non-null    object
#  10  Number of Presenters       320 non-null    int64
#  11  Male Presenters            281 non-null    float64
#  12  Female Presenters          149 non-null    float64
# ...

# %% [markdown]
# ## Number of episodes and pitches in each season

# %%
# Group the data by "Season Number" and get the counts
season_counts = df.groupby('Season Number').agg({'Episode Number': 'nunique', 'Pitch Number': 'count'})

# Renaming the columns for clarity
season_counts = season_counts.rename(columns={'Episode Number': 'Number of Episodes', 'Pitch Number': 'Number of Pitches'})

# Display the season counts with aligned headings
print(season_counts.to_string(justify='left'))
# Out:
#                Number of Episodes  Number of Pitches
# Season Number
# 1              37                  152
# 2              51                  168

# %% [markdown]
# #### Season 1 had 37 episodes with 152 Startups that pitched to the sharks

# %% [markdown]
# #### Season 2 had 51 episodes with 168 Startups that pitched to the sharks

# %% [markdown]
# ## Industry-wise Startups

# %%
shark_tank_season1 = df.loc[df['Season Number']==1]
shark_tank_season2 = df.loc[(df['Season Number']==2)]

# %%
import matplotlib.pyplot as plt

# Calculate the value counts of industries in season 1
industry_counts = shark_tank_season1['Industry'].value_counts().sort_values(ascending=True)

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.barh(industry_counts.index, industry_counts.values, color='steelblue')
plt.xlabel('Number of Startups')
plt.ylabel('Industry')
plt.title('Shark Tank India Season 1 - Industry-wise Startups')
plt.tight_layout()

# Show the graph
plt.show()

# %%
# Calculate the value counts of industries in season 2
industry_counts2 = shark_tank_season2['Industry'].value_counts().sort_values(ascending=True)

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.barh(industry_counts2.index, industry_counts2.values, color='steelblue')
plt.xlabel('Number of Startups')
plt.ylabel('Industry')
plt.title('Shark Tank India Season 2 - Industry-wise Startups')
plt.tight_layout()

# Show the graph
plt.show()

# %% [markdown]
# ## Gender-wise Distribution of pitchers

# %%
print("")
print("Total pitchers -", int(df['Number of Presenters'].sum()), "\n")
print("Total male pitchers -", int(df['Male Presenters'].sum()), "\n")
print("Total female pitchers -", int(df['Female Presenters'].sum()), "\n")
print("Total transgender pitchers -", int(df['Transgender Presenters'].sum()), "\n")
print("")
print("COVID entrepreneurs/startups - ", df.loc[df['Started in']==2020]['Startup Name'].count(), sep='')
# Out:
# Total pitchers - 665
#
# Total male pitchers - 484
#
# Total female pitchers - 178
#
# Total transgender pitchers - 3
#
#
# COVID entrepreneurs/startups - 31

# %% [markdown]
# ## Age wise distribution of pitchers

# %%
print(df['Pitchers Average Age'].value_counts(),"\n")
# Out:
# Middle    231
# Young      88
# Old         1
# Name: Pitchers Average Age, dtype: int64

# %% [markdown]
# ## Extreme scenarios

# %%
# Maximum amount requested
print("Maximum amount requested, by a pitcher - Rs.", round(df["Original Ask Amount"].max()/100), "crores")
# Out:
# Maximum amount requested, by a pitcher - Rs. 300 crores

# %%
# Maximum amount requested
print("Maximum amount requested, by a pitcher - Rs.", round(df["Original Ask Amount"].max()/100), "crores")
# Out:
# Maximum amount requested, by a pitcher - Rs. 300 crores

# %% [markdown]
# ## Top 40 Investments

# %%
# Top 40 investments, as per total investment/deal amount (in lakhs)
print(df.groupby('Startup Name')['Total Deal Amount'].max().nlargest(40))


# Select the top 40 investments based on the total deal amount
top_investments = df.sort_values('Total Deal Amount', ascending=False).head(40)

# Generate an array of colors for each bar
colors = np.random.choice(list(plt.cm.colors.CSS4_COLORS.keys()), len(top_investments))

# Create a vertical bar graph with black background
plt.figure(figsize=(12, 8), facecolor='k')
ax = plt.gca()
ax.set_facecolor('k')
plt.bar(top_investments['Startup Name'], top_investments['Total Deal Amount'], color=colors)
plt.xlabel('Startup Name', color='white')
plt.ylabel('Total Deal Amount (in lakhs)', color='white')
plt.title('Top 40 Investments based on Total Deal Amount', color='white')
plt.xticks(rotation=90, color='white')
plt.yticks(color='white')
plt.tight_layout()
# Out:
# Startup Name
# MeduLance             200.0
# Pharmallama           200.0
# UnStop                200.0
# AasVidyalaya          150.0
# Portl                 150.0
# Snitch                150.0
# Stage                 150.0
# Trunome               150.0
# MindPeers             106.0
# Annie                 105.0
# Broomees              100.0
# GearHeadMotors        100.0
# Geeani                100.0
# Get-A-Whey            100.0
# HammerLifestyle       100.0
# Haqdarshak            100.0
# Hoovu                 100.0
# HumpyA2               100.0
# INACAN                100.0
# InsuranceSamadhan     100.0
# Janitri               100.0
# NeoMotion             100.0
# NishHair              100.0
# PadCare               100.0
# Proxgy                100.0
# RaisingSuperstars     100.0
# RevampMoto            100.0
# Rubans                100.0
# Sahayatha             100.0
# SkippiIcePops         100.0
# SunfoxTechnologies    100.0
# TheGreenSnack         100.0
# ...

# %% [markdown]
# ## Amount Invested by sharks

# %%
# Season 1
Amount_s1 = [shark_tank_season1['Ashneer Investment Amount'].sum(), shark_tank_season1['Namita Investment Amount'].sum(), shark_tank_season1['Anupam Investment Amount'].sum(),
             shark_tank_season1['Vineeta Investment Amount'].sum(), shark_tank_season1['Aman Investment Amount'].sum(), shark_tank_season1['Peyush Investment Amount'].sum(),
             shark_tank_season1['Ghazal Investment Amount'].sum()]
name_s1 = ['Ashneer', 'Namita', 'Anupam', 'Vineeta', 'Aman', 'Peyush', 'Ghazal']

# Season 2
Amount_s2 = [shark_tank_season2['Namita Investment Amount'].sum(), shark_tank_season2['Anupam Investment Amount'].sum(), shark_tank_season2['Vineeta Investment Amount'].sum(),
             shark_tank_season2['Aman Investment Amount'].sum(), shark_tank_season2['Peyush Investment Amount'].sum(), shark_tank_season2['Amit Investment Amount'].sum()]
name_s2 = ['Namita', 'Anupam', 'Vineeta', 'Aman', 'Peyush', 'Amit']

# Set the style
plt.style.use('seaborn-darkgrid')

# Create subplots for both seasons
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot for Season 1
ax1.bar(name_s1, Amount_s1, color='steelblue')
ax1.set_xticklabels(name_s1, rotation=45, ha='right')
ax1.set_ylabel('Total Amount (in lakhs)', fontsize=12)
ax1.set_title('Total Investment Amount by Sharks - Season 1', fontsize=14)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
for index, d in enumerate(Amount_s1):
    ax1.text(x=index, y=d + 2, s=f"{round(d, 2)}", ha='center', fontsize=10)

# Plot for Season 2
ax2.bar(name_s2, Amount_s2, color='steelblue')
ax2.set_xticklabels(name_s2, rotation=45, ha='right')
ax2.set_ylabel('Total Amount (in lakhs)', fontsize=12)
ax2.set_title('Total Investment Amount by Sharks - Season 2', fontsize=14)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
for index, d in enumerate(Amount_s2):
    ax2.text(x=index, y=d + 2, s=f"{round(d, 2)}", ha='center', fontsize=10)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.4);

# Show the graph
plt.show();
# Out:
# C:\Users\manish\AppData\Local\Temp\ipykernel_16012\145453805.py:13: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# C:\Users\manish\AppData\Local\Temp\ipykernel_16012\145453805.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(name_s1, rotation=45, ha='right')
# C:\Users\manish\AppData\Local\Temp\ipykernel_16012\145453805.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(name_s2, rotation=45, ha='right')

# %% [markdown]
# ## Individual shark's Investments (OG 4 sharks)

# %% [markdown]
# ### Ashneer's Investments

# %%
print("Total investments by Ashneer", df[df['Ashneer Investment Amount']>=0][['Ashneer Investment Amount']].count().to_string()[-2:])
print("")
print("Investment amount by Ashneer", round(df['Ashneer Investment Amount'].sum()/100, 2), "crores")
print("")
print("Equity received by Ashneer", round(df['Ashneer Investment Equity'].sum(), 2), "% in different companies")
print("")
print("Debt/loan amount by Ashneer", round(df['Ashneer Debt Amount'].sum()/100, 2), "crores\n")
# Out:
# Total investments by Ashneer 21
#
# Investment amount by Ashneer 5.39 crores
#
# Equity received by Ashneer 93.24 % in different companies
#
# Debt/loan amount by Ashneer 1.14 crores

# %% [markdown]
# ### Namita Thapar's Investments

# %%
print("Total investments by Namita", df[df['Namita Investment Amount']>0][['Namita Investment Amount']].count().to_string()[-2:])
print("")
print("Investment amount by Namita", round(df['Namita Investment Amount'].sum()/100, 2), "crores")
print("")
print("Equity received by Namita", round(df['Namita Investment Equity'].sum(), 2), "% in different companies")
print("")
print("Debt/loan amount by Namita", round(df['Namita Debt Amount'].sum()/100, 2), "crores\n")
# Out:
# Total investments by Namita 66
#
# Investment amount by Namita 20.98 crores
#
# Equity received by Namita 301.59 % in different companies
#
# Debt/loan amount by Namita 5.25 crores

# %% [markdown]
# Anupam Mittal's Investments

# %% [markdown]
# ### Anupam Mittal's Investments

# %%
print("Total investments by Anupam", df[df['Anupam Investment Amount']>=0][['Anupam Investment Amount']].count().to_string()[-2:])
print("")
print("Investment amount by Anupam", round(df['Anupam Investment Amount'].sum()/100, 2), "crores")
print("")
print("Equity received by Anupam", round(df['Anupam Investment Equity'].sum(), 2), "% in different companies")
print("")
print("Debt/loan amount by Anupam", round(df['Anupam Debt Amount'].sum()/100, 2), "crores\n")
# Out:
# Total investments by Anupam 51
#
# Investment amount by Anupam 14.51 crores
#
# Equity received by Anupam 305.83 % in different companies
#
# Debt/loan amount by Anupam 0.98 crores

# %% [markdown]
# ### Aman Gupta's Investments

# %%
print("Total investments by Aman", df[df['Aman Investment Amount']>=0][['Aman Investment Amount']].count().to_string()[-2:])
print("")
print("Investment amount by Aman", round(df['Aman Investment Amount'].sum()/100, 2), "crores")
print("")
print("Equity received by Aman", round(df['Aman Investment Equity'].sum(), 2), "% in different companies")
print("")
print("Debt/loan amount by Aman", round(df['Aman Debt Amount'].sum()/100, 2), "crores\n")
# Out:
# Total investments by Aman 73
#
# Investment amount by Aman 25.1 crores
#
# Equity received by Aman 260.93 % in different companies
#
# Debt/loan amount by Aman 3.11 crores

# %% [markdown]
# ## Trend of total investment amount by season

# %%
total_investment_by_season = df.groupby('Season Number')['Total Deal Amount'].sum()
print("Total Investment Amount by Season:")
print(total_investment_by_season)

print("")
print("")

plt.figure(figsize=(8, 6))
plt.plot(total_investment_by_season.index, total_investment_by_season.values, marker='o')
plt.xlabel('Season Number')
plt.ylabel('Total Investment Amount (in lakhs)')
plt.title('Total Investment Amount by Season')
plt.xticks(total_investment_by_season.index)
plt.grid(True)
plt.show()
# Out:
# Total Investment Amount by Season:
# Season Number
# 1    4024.60106
# 2    6981.00000
# Name: Total Deal Amount, dtype: float64

# %% [markdown]
# ## Distribution of startups across industries (TOP 5)

# %%
# Count the number of startups in each industry
startup_counts_by_industry = df['Industry'].value_counts()

# Select the top 5 industries
top_industries = startup_counts_by_industry.head(5)

# Create a pie chart to visualize the distribution of startups across industries
plt.figure(figsize=(8, 8))
plt.pie(top_industries, labels=top_industries.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Startups across Industries')
plt.axis('equal')
plt.show()
